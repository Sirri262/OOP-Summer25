# %%
class Student:
    def __init__(self, name,index_number):
        self.name = name
        self.index_number = index_number
    def greeting(self):
        print(f"Hello, my name is {self.name}, and my index number is {self.index_number}")
student1 = Student("Sirri","34854")
student1.greeting()
# Out:
# Hello, my name is Sirri, and my index number is 34854
